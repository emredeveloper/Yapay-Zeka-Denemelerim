# %%
#!pip install torch

# %%
import torch
import torch.nn as nn

# Kelime sayısı (vocab_size) ve embedding boyutu (embedding_dim) tanımla
vocab_size = 10000
embedding_dim = 128

# Embedding katmanı oluştur
embedding_layer = nn.Embedding(vocab_size, embedding_dim)

# Örnek bir kelime dizisi oluştur (örneğin bir cümle)
sentence = torch.tensor([1, 2, 3, 4, 5])  # 5 kelime

# Kelime dizisini embedding katmanına ver
embedded_sentence = embedding_layer(sentence)

# Çıktıyı yazdır
print(embedded_sentence.shape)
# Out:
# torch.Size([5, 128])

# %%
import torch
import torch.nn as nn

# Kelime sayısı (vocab_size) ve embedding boyutu (embedding_dim) tanımla
vocab_size = 10000
embedding_dim = 128

# Embedding katmanı oluştur
embedding_layer = nn.Embedding(vocab_size, embedding_dim)

# Örnek bir cümle oluştur
sentence = "Bu bir örnek cümle"

# Kelimeleri sayıya dönüştür (örneğin, kelime -> sayı)
word_to_index = {"Bu": 1, "bir": 2, "örnek": 3, "cümle": 4}
indexed_sentence = [word_to_index[word] for word in sentence.split()]

# Tensor'a dönüştür
indexed_sentence = torch.tensor(indexed_sentence)

# Kelime dizisini embedding katmanına ver
embedded_sentence = embedding_layer(indexed_sentence)

# Çıktıyı yazdır
print(embedded_sentence.shape)
print(embedded_sentence)
# Out:
# torch.Size([4, 128])
# tensor([[-5.7089e-01,  1.6686e+00, -1.0107e+00, -8.7390e-01, -1.3330e+00,
#          -9.0574e-01,  9.0761e-01,  1.7849e+00, -1.3340e+00,  1.0074e+00,
#           1.2201e-01, -3.3653e-01,  8.8136e-01,  1.6383e-01, -2.4243e-02,
#          -1.0154e+00,  8.8920e-02, -2.6492e-01, -3.6303e-01, -4.9926e-02,
#           2.2110e-01, -1.2272e+00, -3.9043e-01,  7.8744e-01, -1.3238e+00,
#           3.3694e-01,  5.4910e-02,  2.0425e+00, -6.9309e-01,  1.5654e+00,
#          -1.9669e-02, -2.0344e-01,  6.1853e-01,  7.4979e-01, -9.3880e-01,
#          -2.4474e+00,  8.3325e-02, -1.1094e+00,  7.6280e-01, -1.3448e+00,
#           6.2124e-02, -2.2804e+00, -1.4939e+00,  1.7095e+00,  1.7760e+00,
#           5.7221e-01, -5.4839e-01, -7.8544e-01,  1.0835e+00,  1.1927e+00,
#           1.8908e-01,  4.6211e-01,  1.2649e+00,  3.0213e-01,  3.9099e-01,
#          -1.9422e+00,  6.5704e-01, -4.3347e-01,  6.2819e-01,  6.1756e-01,
# ...

# %%
import torch
import torch.nn as nn

# Kelime sayısı (vocab_size) ve embedding boyutu (embedding_dim) tanımla
vocab_size = 10000
embedding_dim = 128

# Embedding katmanı oluştur
embedding_layer = nn.Embedding(vocab_size, embedding_dim)

# Örnek bir cümle oluştur
sentence = "Bu bir örnek cümle dostum"

# Kelimeleri sayıya dönüştür (örneğin, kelime -> sayı)
word_to_index = {"Bu": 1, "bir": 2, "örnek": 3, "cümle": 4, "dostum": 5}
indexed_sentence = [word_to_index[word] for word in sentence.split()]

# Tensor'a dönüştür
indexed_sentence = torch.tensor(indexed_sentence)

# Kelime dizisini embedding katmanına ver
embedded_sentence = embedding_layer(indexed_sentence)

# Vektörleri kelimelere dönüştür
index_to_word = {v: k for k, v in word_to_index.items()}
decoded_sentence = [index_to_word[i.item()] for i in indexed_sentence]

# Çıktıyı yazdır
print(decoded_sentence)
# Out:
# ['Bu', 'bir', 'örnek', 'cümle', 'dostum']

# %%
word_to_index.items()
# Out:
# dict_items([('Bu', 1), ('bir', 2), ('örnek', 3), ('cümle', 4), ('dostum', 5)])
